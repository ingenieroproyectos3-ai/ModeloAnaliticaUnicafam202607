# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenieroproyectos3-ai/ModeloAnaliticaUnicafam202607/blob/main/Ejercicio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio 1

# %%
#Declara dos variables A y B con los valores 10 y 3 respectivamente
a=10
b=3
print(a)
print(b)
# Out:
# 10
# 3

# %% [markdown]
# ## Ejercicio 2

# %%
#Calcula la suma de a y b y asígnale a una variable suma
suma=a+b
print(suma)
# Out:
# 13

# %% [markdown]
# ## Ejercicio 3

# %%
#Calcula la resta de a y b y asignale una variable resta
resta=a-b
print(resta)
# Out:
# 7

# %% [markdown]
# ## Ejercicio 4

# %%
#Calcula la multiplicacion de a y b y asignale a una variable multiplicacion
mult=a*b
print(mult)
# Out:
# 30

# %% [markdown]
# ## Ejercicio 5

# %%
## Calcula la división de a entre b y asígnala a una variable division
div=float(a/b)
print(div)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Ejercicio 6

# %%
#Calcula el modulo de a y b y asignalo a una variable modulo
mod=a%b
print(mod)
# Out:
# 1

# %% [markdown]
# ## Ejercicio 7

# %%
#Calcula la potencia de a elevado a la b y asignala a una variable potencia
pot=a**b
print(pot)
# Out:
# 1000

# %% [markdown]
# ## Ejercicio 8

# %%
#Calcula la division entera de a entre b y asignala a una variable division_entera
div_ent=a//b
print(div_ent)
# Out:
# 3
