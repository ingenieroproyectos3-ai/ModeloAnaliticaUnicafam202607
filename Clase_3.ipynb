# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenieroproyectos3-ai/ModeloAnaliticaUnicafam202607/blob/main/Clase_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ESTRUCTURAS DE DATOS**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: Ivan Reina

# %% [markdown]
# ##Listas

# %%
# Una lista vacía
mi_lista=[]
# Lista con varios elementos
mi_lista=[1,2,3,"4",5.0,True]
print(mi_lista[2])
# Out:
# 3

# %%
# Cambios en la lista
mi_lista[0]="Ivan"
print(mi_lista)
# Out:
# ['Ivan', 2, 3, '4', 5.0, True]

# %%
# Agregar elementos a una lista
mi_lista.append("Reina")
print(mi_lista)
# Out:
# ['Ivan', 2, 3, '4', 5.0, True, 'Reina']

# %%
# Agregar elementos a una posición específica
mi_lista.insert(3,"Tunja")
print(mi_lista)
# Out:
# ['Ivan', 2, 3, 'Tunja', '4', 5.0, True, 'Reina']

# %%
# Agregar varios elementos al final de la lista
mi_lista.extend([7,False])
print(mi_lista)
# Out:
# ['Ivan', 2, 3, 'Tunja', '4', 5.0, True, 'Reina', 7, False]

# %%
# Quitar elementos
# Eliminar objetos específicos
mi_lista.remove(True)
print(mi_lista)
# Out:
# ['Ivan', 2, 3, 'Tunja', '4', 5.0, 'Reina', 7, False]

# %%
print("ACTUALIZACIÓN DE DATOS")
valor_buscar=input("Por favor, ingrese el nombre para actualizar:")
valor_reemplazar=input("Ingrese valor a reemplazar:")
mi_lista[mi_lista.index(valor_buscar)]=valor_reemplazar
print("Cambio ejecutado. Imprimiendo resultado")
print(mi_lista)
# Out:
# ACTUALIZACIÓN DE DATOS
# Por favor, ingrese el nombre para actualizar:Ivan
# Ingrese valor a reemplazar:Felipe
# Cambio ejecutado. Imprimiendo resultado
# ['Felipe', 2, 3, 'Tunja', '4', 5.0, 'Reina', 7, False]

# %% [markdown]
# ## **DICCIONARIOS**

# %%
mi_diccionario={
    "Nombre":"Ivan",
    "Ciudad de Nacimiento":"Tunja",
    "Empresa":"Hidromed S.A."
}

# %%
# Acceder a los elementos del diccionario
print(mi_diccionario["Nombre"])
# Out:
# Ivan

# %%
# Modificar un valor en el diccionario
mi_diccionario["Nombre"]="Ivan Felipe"
print(mi_diccionario)
# Out:
# {'Nombre': 'Ivan Felipe', 'Ciudad de Nacimiento': 'Tunja', 'Empresa': 'Hidromed S.A.'}

# %%
# Añadir un elemento al diccionario
mi_diccionario["Profesión"]="Ingeniero de Petróleos"
print(mi_diccionario)
# Out:
# {'Nombre': 'Ivan Felipe', 'Ciudad de Nacimiento': 'Tunja', 'Empresa': 'Hidromed S.A.', 'Profesión': 'Ingeniero de Petróleos'}

# %%
# Eliminar un elemento del diccionario
del mi_diccionario["Ciudad de Nacimiento"]
print(mi_diccionario)
# Out:
# {'Nombre': 'Ivan Felipe', 'Empresa': 'Hidromed S.A.', 'Profesión': 'Ingeniero de Petróleos'}

# %% [markdown]
# ## **CONDICIONALES**

# %%
#Crea un programa que determine si una persona es mayor de edad o menor de edad
print("----VERIFICACIÓN DE EDAD----")
edad=int(input("Ingresa tu edad:"))
if edad<18:
  print(f"Eres menor de edad, tienes:{edad}")
else:
  print(f"Eres mayor de edad, tienes:{edad}")
# Out:
# ----VERIFICACIÓN DE EDAD----
# Ingresa tu edad:17
# Eres menor de edad, tienes:17

# %%
#Condicionales Múltiples
nota=85
if nota>=80:
  if nota>=90:
    print("Excelente")
  elif nota>=80 and nota<90:
    print("Aceptable")
else:
  print("Insuficiente")
# Out:
# Aceptable
