# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenieroproyectos3-ai/ModeloAnaliticaUnicafam202607/blob/main/Taller_Practico_13_Julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **MENÚ DE MANEJO DE DATOS PERSONALES**
#
# ## Estudiante: Ivan Reina

# %% [markdown]
# ## **Prueba de la Opcion 1**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")


opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 1
# Ingrese el nuevo dato personal: Profesión
# Ingrese el valor de ese dato personal: Ingeniero de Petróleos
#
#  Perfil actualizado:
# {'Nombre': 'Ivan Reina', 'Edad': '30', 'Ciudad': 'Bogotá', 'Hobbies': ['Fútbol', 'Viajar', 'Videojuegos'], 'Profesión': 'Ingeniero de Petróleos'}

# %% [markdown]
# ## **Prueba de la Opcion 2**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")

opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 2
# Ingrese el dato personal que desea actualizar: Nombre
# Ingrese el nuevo valor del dato: Felipe Pérez
#
# Dato actualizado correctamente.
# {'Nombre': 'Felipe Pérez', 'Edad': '30', 'Ciudad': 'Bogotá', 'Hobbies': ['Fútbol', 'Viajar', 'Videojuegos']}

# %% [markdown]
# ## **Prueba de la Opcion 3**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")

opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 3
# Ingrese el dato personal que desea eliminar: Edad
#
# Dato personal eliminado correctamente.
# {'Nombre': 'Ivan Reina', 'Ciudad': 'Bogotá', 'Hobbies': ['Fútbol', 'Viajar', 'Videojuegos']}

# %% [markdown]
# ## **Prueba de la Opcion 4**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")

opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 4
# Ingrese el dato personal que desea eliminar: Ciudad
#
# Dato personal eliminado correctamente.
# {'Nombre': 'Ivan Reina', 'Edad': '30', 'Hobbies': ['Fútbol', 'Viajar', 'Videojuegos']}

# %% [markdown]
# ## **Prueba de la Opcion 5**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")

opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 5
# Ingrese el dato personal que desea consultar: Hobbies
# Hobbies ['Fútbol', 'Viajar', 'Videojuegos']

# %% [markdown]
# ## **Prueba de la Opcion 6**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")

opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 6
#
#  ---Mi perfil completo:
# {'Nombre': 'Ivan Reina', 'Edad': '30', 'Ciudad': 'Bogotá', 'Hobbies': ['Fútbol', 'Viajar', 'Videojuegos']}

# %% [markdown]
# ## **Prueba de la Opcion Inválida**

# %%
# Diccionario con los datos personales

perfil={
    "Nombre":"Ivan Reina",
    "Edad":"30",
    "Ciudad":"Bogotá",
    "Hobbies":["Fútbol","Viajar","Videojuegos"]
}

# Menú

print("---MENÚ DE MI PERFIL---")
print("1. Agregar un dato nuevo")
print("2. Actualizar un dato")
print("3. Eliminar un dato")
print("4. Eliminar un dato con .pop()")
print("5. Consultar un dato")
print("6. Mostrar el perfil")

opcion=input("Seleccione una opción: ")

# Agregar un dato nuevo
if opcion=="1":
  clave=input("Ingrese el nuevo dato personal: ")
  valor=input("Ingrese el valor de ese dato personal: ")
  perfil[clave]=valor
  print("\n Perfil actualizado: ")
  print(perfil)

# Actualizar un dato existente
elif opcion == "2":
    clave = input("Ingrese el dato personal que desea actualizar: ")

    if clave in perfil:
        nuevo_valor = input("Ingrese el nuevo valor del dato: ")
        perfil[clave] = nuevo_valor
        print("\nDato actualizado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con "del"
elif opcion == "3":
    clave = input("Ingrese el dato personal que desea eliminar: ")
    if clave in perfil:
        del perfil[clave]
        print("\nDato personal eliminado correctamente.")
        print(perfil)
    else:
        print("El dato personal no existe en el diccionario.")

# Eliminar un dato con ".pop()"
elif opcion=="4":
      clave = input("Ingrese el dato personal que desea eliminar: ")
      if clave in perfil:
          valor = perfil.pop(clave)
          print("\nDato personal eliminado correctamente.")
          print(perfil)
      else:
          print("La clave no existe en el diccionario.")

# Consultar un dato personal
elif opcion == "5":
    clave = input("Ingrese el dato personal que desea consultar: ")
    valor = perfil.get(clave, "No disponible")
    print(clave, valor)

# Mostrar el perfil completo
elif opcion == "6":
    print("\n ---Mi perfil completo:")
    print(perfil)
else:
  print("Opción no válida.")
# Out:
# ---MENÚ DE MI PERFIL---
# 1. Agregar un dato nuevo
# 2. Actualizar un dato
# 3. Eliminar un dato
# 4. Eliminar un dato con .pop()
# 5. Consultar un dato
# 6. Mostrar el perfil
# Seleccione una opción: 9
# Opción no válida.
