# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenieroproyectos3-ai/ModeloAnaliticaUnicafam202607/blob/main/Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Este es un comentario de una sola linea
print("Hola mundo")
# Out:
# Hola mundo

# %%
"""""
Este es un comentario de de
varias lineas
"""
# Out:
# '""\nEste es un comentario de de \nvarias lineas\n'

# %% [markdown]
# ## VARIABLES

# %%
var="Hola mundo"
print(var)
# Out:
# Hola mundo

# %%
#1. Las variables preferiblemente se escriben en minuscula
#2. Las variables no deben tener espacios
#3. Las variables no deben contener caracteres especiales

# %% [markdown]
# ## TIPOS DE DATOS

# %%
#Enteros
entero=5
entero_explicito=int(5)

#Decimales
decimal=5.0
decimal_explicito=float(5.0)

# %%
type(entero)
# Out:
# int

# %% [markdown]
# ## OPERADORES ARITMÉTICOS

# %%
a=10
b=5
c=a+b
print(a+b)
print(c)
# Out:
# 15
# 15

# %%
#DIVISION ENTERA
print(a//b)
# Out:
# 2

# %%
#MODULO
print(a%b)
# Out:
# 0

# %%
#EXPONENCIACION
print(b**2)
# Out:
# 25

# %%
#ASIGNACION COMPUESTA
b+=2
print(b)
# Out:
# 7

# %% [markdown]
# ## Textos

# %%
cadena="Python es genial"
print(cadena[5])
# Out:
# n

# %%
#Extraer la palabra Python
print(cadena[0:6])
# Out:
# Python

# %%
#Extraer la palabra genial
print(cadena[10:16])
# Out:
# genial

# %%
#Concatenación de valores
palabra_1="Hola"
palabra_2="mundo"
print(palabra_1+", "+palabra_2)
# Out:
# Hola, mundo

# %%
#CAMBIOS DE FORMATO
print(cadena.upper())
# Out:
# PYTHON ES GENIAL
