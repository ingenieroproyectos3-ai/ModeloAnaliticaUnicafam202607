# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenieroproyectos3-ai/ModeloAnaliticaUnicafam202607/blob/main/Ejercicio_1_Creacion_y_Modificacion_de_Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Ejercicio 1: Creación y Modificación de Listas**

# %%
# 1.Crea una lista llamada números que contenga los números del 1 al 5.
lista=[1,2,3,4,5]
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 2. Añade el número 6 al final de la lista numeros.
lista.append(6)
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 3. Cambia el segundo elemento de la lista numeros a 10.
lista[1]=10
print(lista)
# Out:
# [1, 10, 3, 4, 5, 6]

# %%
# 4. Elimina el cuarto elemento de la lista números.
lista.remove(lista[3])
print(lista)
# Out:
# [1, 10, 3, 5, 6]
